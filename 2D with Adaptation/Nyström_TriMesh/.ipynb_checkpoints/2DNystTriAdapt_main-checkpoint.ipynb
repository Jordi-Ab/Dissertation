# %%
import numpy as np
from meshtools import *
import NeuralField as nf
import ConnectivityKernel as ck
import FiringRate as fr
import QuadratureInTriangles as Qtri
import InitialConditions as ic
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.mlab import griddata
from scipy.integrate import ode
# %matplotlib inline
# Out:
# ----------------------------------------------------------------------
# ImportError                          Traceback (most recent call last)
# <ipython-input-1-b5daebe78c1c> in <module>()
#       1 import numpy as np
#       2 from meshtools import *
# ----> 3 import NeuralField as nf
#       4 import ConnectivityKernel as ck
#       5 import FiringRate as fr
#
# ImportError: No module named 'NeuralField'

# %%
# Used for Plotting 3D result on linear vectors
def grid(x, y, z, resX=100, resY=100):
    "Convert 3 column data to matplotlib grid"
    xi = np.linspace(min(x), max(x), resX)
    yi = np.linspace(min(y), max(y), resY)
    Z = griddata(x, y, z, xi, yi)
    X, Y = np.meshgrid(xi, yi)
    return X, Y, Z

# %%
# Generate Mesh
Lx=-20; Ux=20
Ly=-20; Uy=20
length = 3
p,v=RectangleSegments([Ux,Uy],[Lx, Ly],edge_length=length)
mesh_pts, elems = DoTriMesh(p,v,edge_length=length)
NT = len(elems) # Number of triangles
print("Number of Elements = " + str(NT))
# Out:
# Number of Elements = 540

# %%
# plot mesh
plt.triplot(mesh_pts[:, 0], mesh_pts[:, 1], elems)
# Out:
# [<matplotlib.lines.Line2D at 0x11233a358>,
#  <matplotlib.lines.Line2D at 0x11233a400>]

# %%
Np = 2 # Desired number of gauss points.

gwp = Qtri.getWeightsAndPoints(Np)

weights = gwp[:,2]
x_hat = gwp[:,1]
y_hat = gwp[:,0]

Ng = len(weights) # Actual Number of Gauss points.

# %%
# Assemble Mesh of Interior Points
xs = []
As = []
for l, elem in enumerate(elems):
    v1,v2,v3 = mesh_pts[elem] # Get vertices of the element
    A_l = Qtri.computeArea(v1,v2,v3)
    As.append(A_l)
    for j in range(len(weights)):
        new_point = Qtri.mapX(v1, v2, v3, x_hat[j], y_hat[j])
        xs.append(new_point)
xs = np.array(xs)
As = np.array(As)

# %%
# Initialize Connectivity Kernel
b = 1
kernel = ck.ConnectivityKernel1(b)

# %%
# Assemble Synaptic Matrix
n = xs.shape[0]
W = np.zeros((n,n))
for i in range(n):
    for j in range(n):
        l = int(np.floor(j/Ng)) # Element At
        A = As[l]
        r = j - l*Ng # Interior point of element at
        rho = weights[r]
        w = kernel.evaluateAt(xs[i,:] - xs[j,:])
        W[i,j] = w*A*rho
W.shape
# Out:
# (1620, 1620)

# %% [markdown]
# ### Time step using standard ODE solvers

# %%
# Initialize Firing Rate
p_mu = 50
p_h = 0.6
f_rate = fr.FiringRate1(p_mu, p_h)

# Initialize Neural Field
p_g = 1
p_alph = 1.2
NeuralField = nf.NeuralField(W, f_rate, p_alph, p_g)
neural_field = lambda t,v: NeuralField.evaluateAt(t,v) # Callable function

# %%
# Evaluate the Initial Condition at each point inside the grid.
u0 = [] # Synaptic Potential
a0 = [] # Adaptation
for x in xs:
    init_cond = ic.initCondition1(x)
    u0.append(init_cond)
    a0.append(init_cond)
v0 = np.array(u0 + a0)

# %%
method = ode(neural_field).set_integrator("dopri5")
method.set_initial_value(v0)
final_t = 15
dt = 0.1
vs = []
time_points = []
while method.t < final_t:
    next_t = method.t+dt
    time_points.append(next_t)
    next_v = method.integrate(next_t)
    vs.append(next_v)

# %%
fig1 = plt.figure(figsize=(10,4))

# Plot initial time of Synaptic Activity
ax11 = fig1.add_subplot(121)
xx0, yy0, uu0 = grid(xs[:,0], xs[:,1], vs[0][:Ng*NT])
cont11 = ax11.contourf(xx0, yy0, uu0, 20, cmap=plt.get_cmap('viridis'))
ax11.set_title("Synaptic Activity at Initial Time")
plt.colorbar(cont11)

# Plot initial time of Adaptation
ax21 = fig1.add_subplot(122)
xx0, yy0, aa0 = grid(xs[:,0], xs[:,1], vs[0][Ng*NT:])
cont21 = ax21.contourf(xx0, yy0, aa0, 20, cmap=plt.get_cmap('viridis'))
ax21.set_title("Adaptation at Initial Time")
plt.colorbar(cont21)

fig2 = plt.figure(figsize=(10,4))
# Plot final time of Synaptic Activity
ax12 = fig2.add_subplot(121)
xn, yn, un1 = grid(xs[:,0], xs[:,1], vs[-1][:Ng*NT])
cont12 = ax12.contourf(xn, yn, un1, 20, cmap=plt.get_cmap('viridis'))
ax12.set_title("Synaptic Activity at Final Time")
plt.colorbar(cont12)

# Plot final time of Adaptation
ax22 = fig2.add_subplot(122)
xn, yn, un2 = grid(xs[:,0], xs[:,1], vs[-1][Ng*NT:])
cont22 = ax22.contourf(xn, yn, un2, 20, cmap=plt.get_cmap('viridis'))
ax22.set_title("Adaptation at Final Time")
plt.colorbar(cont22)

plt.savefig("IC1_"+str(NT)+"elems_("+str(p_h)+")h.png")
