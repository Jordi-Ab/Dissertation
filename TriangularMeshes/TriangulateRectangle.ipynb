# %%
from meshtools import *
import numpy as np
from Delaunay_mesh import Delaunay
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
# Triangulate mesh
p,v=RectangleSegments([3,1],[-2,-2],edge_length=1)
mesh_pts, elems = DoTriMesh(p,v,edge_length=1)

# %%
# plot mesh
pt.triplot(mesh_pts[:, 0], mesh_pts[:, 1], elems)
pt.xlim(-3,4)
pt.ylim(-3,2)
# Out:
# (-3, 2)
